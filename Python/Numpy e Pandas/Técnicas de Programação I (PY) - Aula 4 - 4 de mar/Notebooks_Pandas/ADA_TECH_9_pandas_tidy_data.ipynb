# %% [markdown]
# <img src='letscodebr_cover.jpeg' align='left' width=100%/>

# %% [markdown]
# # Ada Tech [DS-PY-004] Técnicas de Programação I (PY) Aulas 4 e 5 : Pandas - Tidy Data.

# %% [markdown]
# ## Intro
#
# Dizemos que um conjunto de dados é ordenado quando:
# * Cada variável é uma coluna
# * Cada observação é uma linha
# * Cada tipo de unidade observacional forma uma tabela
#
# Algumas definições:
# * Variável: É a medida de um atributo, por exemplo, peso, altura, etc.
# * Valor: É a medida que uma variável leva para uma observação.
# * Observação: Todas as observações assumem o mesmo tipo de valores para cada variável.

# %% [markdown]
# ## Dataset
#
# Usaremos o conjunto de dados das obras do [Met](https://github.com/metmuseum/openaccess/) (Museu Metropolitano de Arte) que vimos na aula de Limpeza de Dados.
#
# Analisando o conjunto de dados do Met vemos que os dados dos artistas estão na mesma tabela que os dados das obras, quebrando a terceira regra que diz “Cada tipo de unidade observacional forma uma tabela”.
#
# Vamos ver como resolver esse ponto.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Importamos os dados
#
# Nós vemos o quão grande é o conjunto de dados e imprimimos os primeiros registros.

# %%
# local
data_location = "../Data/MetObjects_sample.csv"

data = pd.read_csv(data_location)

data.dtypes
# Out:
# Unnamed: 0                   int64
# Object Number               object
# Is Highlight                  bool
# Is Public Domain              bool
# Is Timeline Work              bool
# Object ID                    int64
# Department                  object
# AccessionYear               object
# Object Name                 object
# Title                       object
# Culture                     object
# Period                      object
# Dynasty                     object
# Reign                       object
# Portfolio                   object
# Artist Role                 object
# Artist Prefix               object
# Artist Display Name         object
# Artist Display Bio          object
# Artist Suffix               object
# Artist Alpha Sort           object
# Artist Nationality          object
# Artist Begin Date           object
# Artist End Date             object
# Artist Gender               object
# Artist ULAN URL             object
# Artist Wikidata URL         object
# Object Date                 object
# Object Begin Date            int64
# Object End Date              int64
# Medium                      object
# Dimensions                  object
# Credit Line                 object
# Geography Type              object
# City                        object
# State                       object
# County                      object
# Country                     object
# Region                      object
# Subregion                   object
# Locale                      object
# Locus                       object
# Excavation                  object
# River                       object
# Classification              object
# Rights and Reproduction     object
# Link Resource               object
# Object Wikidata URL         object
# Metadata Date              float64
# Repository                  object
# Tags                        object
# Tags AAT URL                object
# dtype: object

# %%
data.head(3)
# Out:
#    Unnamed: 0  Object Number  Is Highlight  Is Public Domain  \
# 0      297513  Inst.1980.3.1         False             False
# 1      366196     175T49 R43          True             False
# 2      380983         WW.550         False             False
#
#    Is Timeline Work  Object ID           Department AccessionYear  \
# 0             False     442985          Islamic Art           NaN
# 1             False     591826        The Libraries           NaN
# 2             False     650203  Drawings and Prints           NaN
#
#                Object Name                    Title  ... Excavation River  \
# 0  Illustrated single work  Illustrated Single Work  ...        NaN   NaN
# 1                      NaN      Vita del Tintoretto  ...        NaN   NaN
# 2                    Print    Flowers and Dragonfly  ...        NaN   NaN
#
#   Classification Rights and Reproduction  \
# 0        Codices                     NaN
# 1            NaN                     NaN
# 2         Prints                     NaN
#
#                                        Link Resource  \
# 0  http://www.metmuseum.org/art/collection/search...
# 1  http://www.metmuseum.org/art/collection/search...
# 2  http://www.metmuseum.org/art/collection/search...
#
#                        Object Wikidata URL Metadata Date  \
# 0                                      NaN           NaN
# 1  https://www.wikidata.org/wiki/Q29385980           NaN
# 2                                      NaN           NaN
#
#                                  Repository                 Tags  \
# 0  Metropolitan Museum of Art, New York, NY          Abstraction
# 1  Metropolitan Museum of Art, New York, NY                  NaN
# 2  Metropolitan Museum of Art, New York, NY  Dragonflies|Flowers
#
#                                         Tags AAT URL
# 0          http://vocab.getty.edu/page/aat/300056508
# 1                                                NaN
# 2  http://vocab.getty.edu/page/aat/300310476|http...
#
# [3 rows x 52 columns]

# %% [markdown]
# ## Tidy data

# %% [markdown]
# Analisando o conjunto de dados do Met vemos que os dados dos artistas estão na mesma tabela que os dados das obras, quebrando a terceira regra que diz “Cada tipo de unidade observacional forma uma tabela”.
#
# Neste caso devemos ter uma tabela para Obra e outra para Artista.
#
# Vamos separar esses dados em duas tabelas e eliminar duplicatas na tabela de artistas.

# %%
data_artist_columns = ['Artist Role', 'Artist Prefix', 'Artist Display Name',
                       'Artist Display Bio', 'Artist Suffix', 'Artist Alpha Sort',
                       'Artist Nationality', 'Artist Begin Date', 'Artist End Date',
                       'Artist Gender', 'Artist ULAN URL', 'Artist Wikidata URL'
                      ]

data_artist  = data.loc[ : , data_artist_columns]
print(data_artist.shape)
# Out:
# (4743, 12)

# %%
data_artist.head(3)
# Out:
#         Artist Role Artist Prefix             Artist Display Name  \
# 0            Artist           NaN            Mohammad Aslam Kamal
# 1            Author           NaN                   Carlo Ridolfi
# 2  Artist|Publisher           NaN  Maria Pranke|Wiener Werkstätte
#
#                                   Artist Display Bio Artist Suffix  \
# 0                                            b. 1939           NaN
# 1                   Italian, Lonigo 1594–1658 Venice           NaN
# 2  Hungarian, Pándorfalu Parndorf, Hungary 1891–1...           NaN
#
#                  Artist Alpha Sort Artist Nationality Artist Begin Date  \
# 0             Kamal Mohammad Aslam          Pakistani        1914
# 1                   Ridolfi, Carlo            Italian        1594
# 2  Pranke, Maria|Wiener Werkstätte          Hungarian        1891
#
#   Artist End Date Artist Gender                              Artist ULAN URL  \
# 0      1990                 NaN                                          NaN
# 1      1658                 NaN   http://vocab.getty.edu/page/ulan/500013305
# 2      1972                   |  |http://vocab.getty.edu/page/ulan/500268774
#
#                       Artist Wikidata URL
# 0                                     NaN
# 1   https://www.wikidata.org/wiki/Q776990
# 2  |https://www.wikidata.org/wiki/Q241338

# %% [markdown]
# Vamos ver se há registros duplicados em data_artist.
#
# Consideramos duplicados os registros que correspondem aos campos "Artist Display Name", "Artist Role".

# %%
artist_duplicated = data_artist.duplicated(subset = ["Artist Display Name", "Artist Role"])
any(artist_duplicated)
# Out:
# True

# %% [markdown]
# Eliminamos registros duplicados:

# %%
data_artist_unique = data_artist.drop_duplicates(subset = ["Artist Display Name", "Artist Role"], keep = "first")
print(data_artist_unique.shape)
print(data_artist.shape)
# Out:
# (1615, 12)
# (4743, 12)

# %% [markdown]
# Para não perder a associação entre a obra e o artista, na tabela data_object mantemos os campos "Artist Display Name" e "Artist Role", que são os identificadores do artista na tabela data_artist.

# %%
data_artist_columns_key =  ['Artist Prefix', 'Artist Display Bio', 'Artist Suffix', 'Artist Alpha Sort',
                            'Artist Nationality', 'Artist Begin Date', 'Artist End Date',
                            'Artist Gender', 'Artist ULAN URL', 'Artist Wikidata URL'
                           ]

data_object = data.drop(data_artist_columns_key, axis = 'columns')
print(data_object.shape)
data_object.columns
# Out:
# (4743, 42)
# Index(['Unnamed: 0', 'Object Number', 'Is Highlight', 'Is Public Domain',
#        'Is Timeline Work', 'Object ID', 'Department', 'AccessionYear',
#        'Object Name', 'Title', 'Culture', 'Period', 'Dynasty', 'Reign',
#        'Portfolio', 'Artist Role', 'Artist Display Name', 'Object Date',
#        'Object Begin Date', 'Object End Date', 'Medium', 'Dimensions',
#        'Credit Line', 'Geography Type', 'City', 'State', 'County', 'Country',
#        'Region', 'Subregion', 'Locale', 'Locus', 'Excavation', 'River',
#        'Classification', 'Rights and Reproduction', 'Link Resource',
#        'Object Wikidata URL', 'Metadata Date', 'Repository', 'Tags',
#        'Tags AAT URL'],
#       dtype='object')

# %% [markdown]
# Quando removemos as duplicatas, a tabela de artistas passou de 4743 registros para 1615.
#
# Isso resulta em uma melhora no desempenho em termos de espaço e facilita a manutenção da consistência dos valores nos registros. Como desvantagem, precisaremos combinar as duas tabelas para responder a algumas perguntas que envolvem relacionamentos entre colunas em tabelas diferentes.

# %% [markdown]
# ## Revisão de joins con pandas
#
# `merge` `concat` `join` `append`
#
# Como exercício, vamos agora fazer o caminho inverso, partindo de duas tabelas (objetos e artistas) vamos combiná-las para obter um único DataFrame com o conjunto de dados total.

# %% [markdown]
# Como vimos na Prática Guiada 3, os dados contidos nos objetos pandas podem ser combinados usando os métodos
#
# - [`pandas.DataFrame.merge`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html): combina linhas de dois DataFrames com base em uma ou mais chaves. É análogo ao join do SQL.
#
# - [`pandas.concat()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.concat.html): concatenar ou empilhar objetos pandas em qualquer um dos eixos.
#
# - [`pandas.DataFrame.join`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.join.html): adicionar colunas de outro DataFrame.
#
# - [`pandas.DataFrame.append`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.append.html): adicione as linhas de outro DataFrame ao final.

# %% [markdown]
# **Vamos ver um exemplo de `merge`**, vamos comparar seu tamanho com o DataFrame original (antes de dividi-lo em data_objet e data_artist).

# %%
data_all_merge = data_object.merge(data_artist_unique, 
                                   left_on = ['Artist Role', 'Artist Display Name'],
                                   right_on = ['Artist Role', 'Artist Display Name'], 
                                   how = "left"
                                  )

# %%
data_all_merge.shape
# Out:
# (4743, 52)

# %%
data_all_merge.shape
# Out:
# (4743, 52)

# %% [markdown]
# Estamos definindo as colunas 'Artist Role', 'Artist Display Name'  como chaves dos registros para combiná-los em ambos os DataFrames.
#
# Duas linhas serão combinadas no DataFrame resultante se corresponderem aos valores das chaves no Conjunto de dados envolvido na fusão.
#
# `left_on` indica quais colunas do primeiro DataFrame (a da esquerda) são a chave na fusão
#
# `right_on` indica quais colunas do segundo DataFrame (a da direita) são a chave na fusão
#
# `how` indica como combinar os objetos
# * inner: o resultado tem apenas os registros cujas chaves estão em ambos os DataFrames
# * left: o resultado contém todos os registros do primeiro DataFrame (à esquerda), embora a chave possa não estar no segundo DataFrame (à direita)
# * rigth: o resultado tem todos os registros do segundo DataFrame (direita), embora a chave possa não estar no primeiro DataFrame (esquerda)

# %% [markdown]
# Vamos ver um exemplo de `concat`, axis = 1 indica que concatenamos as colunas dos dois DataFrames. Observe que ele não combina as colunas repetidas, mas, em vez disso, o DataFrame resultante tem uma coluna de cada DataFrame.

# %%
data_all_concat = pd.concat([data_object, data_artist_unique],  
                            axis = 1
                           )

print(data_object.shape)
print(data_artist_unique.shape)
print(data_all_concat.shape)

data_all_concat.columns[data_all_concat.columns == 'Artist Display Name']
# Out:
# (4743, 42)
# (1615, 12)
# (4743, 54)
# Index(['Artist Display Name', 'Artist Display Name'], dtype='object')

# %% [markdown]
# **Vamos ver um exemplo de `concat`**, axis = 0 que indica que concatenamos as linhas dos dois DataFrames. Observe que a ordem das colunas não precisa ser a mesma em ambos os DataFrames.

# %%
data_object_1 = data_object.iloc[0 : 10, : ]

columns_reverse = data_object.columns[ : : -1 ]
data_object_2 = data_object.iloc[10 : 20].loc[ : , columns_reverse]

print(data_object_1.shape)
print(data_object_2.shape)
# Out:
# (10, 42)
# (10, 42)

# %%
data_object_1_2 = pd.concat([data_object_1, data_object_2],  
                            axis = 0
                           )

print(data_object_1_2.shape)
data_object_1_2.sample(5)
# Out:
# (20, 42)
#     Unnamed: 0  Object Number  Is Highlight  Is Public Domain  \
# 1       366196     175T49 R43          True             False
# 15      155187        X.21.93         False             False
# 0       297513  Inst.1980.3.1         False             False
# 4       472119     24.63.2060         False             False
# 9       297448       x.165.13         False             False
#
#     Is Timeline Work  Object ID           Department AccessionYear  \
# 1              False     591826        The Libraries           NaN
# 15              True     256657  Greek and Roman Art           NaN
# 0              False     442985          Islamic Art           NaN
# 4              False     838838  Drawings and Prints           NaN
# 9               True     442887          Islamic Art           NaN
#
#                 Object Name                                Title  ...  \
# 1                       NaN                  Vita del Tintoretto  ...
# 15       Statuette of a ram            Bronze statuette of a ram  ...
# 0   Illustrated single work              Illustrated Single Work  ...
# 4                     Print  Victor Hugo, published in Le Masque  ...
# 9               Coin weight                          Coin Weight  ...
#
#    Excavation River Classification Rights and Reproduction  \
# 1         NaN   NaN            NaN                     NaN
# 15        NaN   NaN        Bronzes                     NaN
# 0         NaN   NaN        Codices                     NaN
# 4         NaN   NaN         Prints                     NaN
# 9         NaN   NaN          Glass                     NaN
#
#                                         Link Resource  \
# 1   http://www.metmuseum.org/art/collection/search...
# 15  http://www.metmuseum.org/art/collection/search...
# 0   http://www.metmuseum.org/art/collection/search...
# 4   http://www.metmuseum.org/art/collection/search...
# 9   http://www.metmuseum.org/art/collection/search...
#
#                         Object Wikidata URL Metadata Date  \
# 1   https://www.wikidata.org/wiki/Q29385980           NaN
# 15                                      NaN           NaN
# 0                                       NaN           NaN
# 4                                       NaN           NaN
# 9                                       NaN           NaN
#
#                                   Repository                  Tags  \
# 1   Metropolitan Museum of Art, New York, NY                   NaN
# 15  Metropolitan Museum of Art, New York, NY                  Rams
# 0   Metropolitan Museum of Art, New York, NY           Abstraction
# 4   Metropolitan Museum of Art, New York, NY                   NaN
# 9   Metropolitan Museum of Art, New York, NY  Weights and Measures
#
#                                  Tags AAT URL
# 1                                         NaN
# 15  http://vocab.getty.edu/page/aat/300250287
# 0   http://vocab.getty.edu/page/aat/300056508
# 4                                         NaN
# 9   http://vocab.getty.edu/page/aat/300386648
#
# [5 rows x 42 columns]

# %% [markdown]
# **Vamos ver um exemplo de `join`**. Este método é muito eficiente (melhor do que merge) porque usa os índices dos DataFrames.
#
# Para isso, vamos definir as colunas  'Artist Role' e  'Artist Display Name' como um índice nos dois objetos.
#
# Anteriormente, devemos eliminar os registros que são nulos em qualquer um dos dois campos dos DataFrames.
#
# Os índices podem ser criados em DataFrames com registros nulos nesses campos, mas o método de junção falha nessas condições.

# %%
print("quantidade de números ausentes no campo 'Artist Role' de data_object_index", data_object['Artist Role'].isnull().sum())
print("quantidade de números ausentes no campo 'Artist Role' de data_artist_unique_index", data_artist_unique['Artist Role'].isnull().sum())
print("quantidade de números ausentes no campo 'Artist Display Name' de data_object_index", data_object['Artist Display Name'].isnull().sum())
print("quantidade de números ausentes no campo 'Artist Display Name' de data_artist_unique_index", data_artist_unique['Artist Display Name'].isnull().sum())
# Out:
# quantidade de números ausentes no campo 'Artist Role' de data_object_index 2359
# quantidade de números ausentes no campo 'Artist Role' de data_artist_unique_index 14
# quantidade de números ausentes no campo 'Artist Display Name' de data_object_index 2345
# quantidade de números ausentes no campo 'Artist Display Name' de data_artist_unique_index 1

# %%
data_artist_notnull = data_artist_unique.dropna(subset = ['Artist Role', 'Artist Display Name'], 
                                                how = 'any', 
                                                axis = 0
                                               )

data_object_notnull = data_object.dropna(subset = ['Artist Role', 'Artist Display Name'], 
                                         how = 'any', 
                                         axis = 0
                                        )

# %%
data_artist_notnull_index = data_artist_notnull.set_index(['Artist Role', 'Artist Display Name'])
data_object_notnull_index = data_object_notnull.set_index(['Artist Role', 'Artist Display Name'])

# %%
data_all_join = data_object_notnull_index.join(data_artist_notnull_index, 
                                               lsuffix = "object_", 
                                               rsuffix = "artist_"
                                              )

print(data_all_join.shape)
data_all_join.sample(3)
# Out:
# (2384, 50)
#                                               Unnamed: 0  \
# Artist Role Artist Display Name
# Artist      Anonymous, British, 19th century      466974
# Designer    Margarete Willers                     325265
# Artist      Adelaide Milton de Groot               16393
#
#                                                      Object Number  \
# Artist Role Artist Display Name
# Artist      Anonymous, British, 19th century  Ref.BellaLandauer.54
# Designer    Margarete Willers                          1985.198.76
# Artist      Adelaide Milton de Groot                    67.187.212
#
#                                               Is Highlight  Is Public Domain  \
# Artist Role Artist Display Name
# Artist      Anonymous, British, 19th century         False             False
# Designer    Margarete Willers                        False             False
# Artist      Adelaide Milton de Groot                 False             False
#
#                                               Is Timeline Work  Object ID  \
# Artist Role Artist Display Name
# Artist      Anonymous, British, 19th century             False     824091
# Designer    Margarete Willers                            False     484111
# Artist      Adelaide Milton de Groot                     False      19350
#
#                                                                Department  \
# Artist Role Artist Display Name
# Artist      Anonymous, British, 19th century          Drawings and Prints
# Designer    Margarete Willers                 Modern and Contemporary Art
# Artist      Adelaide Milton de Groot                    The American Wing
#
#                                              AccessionYear        Object Name  \
# Artist Role Artist Display Name
# Artist      Anonymous, British, 19th century           NaN  Print, Trade Card
# Designer    Margarete Willers                         1985     Textile sample
# Artist      Adelaide Milton de Groot                  1967           Painting
#
#                                                                          Title  \
# Artist Role Artist Display Name
# Artist      Anonymous, British, 19th century  Trade Card for Reeve, Bookseller
# Designer    Margarete Willers                                  Bauhaus Archive
# Artist      Adelaide Milton de Groot                          Fern and Peonies
#
#                                               ... Artist Prefix  \
# Artist Role Artist Display Name               ...
# Artist      Anonymous, British, 19th century  ...           NaN
# Designer    Margarete Willers                 ...           NaN
# Artist      Adelaide Milton de Groot          ...           NaN
#
#                                                                  Artist Display Bio  \
# Artist Role Artist Display Name
# Artist      Anonymous, British, 19th century                                    NaN
# Designer    Margarete Willers                     German, Oldenburg 1883–1977 Essen
# Artist      Adelaide Milton de Groot          American, New York 1876–1967 New York
#
#                                              Artist Suffix  \
# Artist Role Artist Display Name
# Artist      Anonymous, British, 19th century           NaN
# Designer    Margarete Willers                          NaN
# Artist      Adelaide Milton de Groot                   NaN
#
#                                                              Artist Alpha Sort  \
# Artist Role Artist Display Name
# Artist      Anonymous, British, 19th century  Anonymous, British, 19th century
# Designer    Margarete Willers                               Willers, Margarete
# Artist      Adelaide Milton de Groot                 de Groot, Adelaide Milton
#
#                                              Artist Nationality  \
# Artist Role Artist Display Name
# Artist      Anonymous, British, 19th century                NaN
# Designer    Margarete Willers                            German
# Artist      Adelaide Milton de Groot                   American
#
#                                              Artist Begin Date  \
# Artist Role Artist Display Name
# Artist      Anonymous, British, 19th century        1800
# Designer    Margarete Willers                       1883
# Artist      Adelaide Milton de Groot                1876
#
#                                               Artist End Date  Artist Gender  \
# Artist Role Artist Display Name
# Artist      Anonymous, British, 19th century       1900                  NaN
# Designer    Margarete Willers                      1977               Female
# Artist      Adelaide Milton de Groot               1967               Female
#
#                                                                          Artist ULAN URL  \
# Artist Role Artist Display Name
# Artist      Anonymous, British, 19th century                                         NaN
# Designer    Margarete Willers                 http://vocab.getty.edu/page/ulan/500125055
# Artist      Adelaide Milton de Groot          http://vocab.getty.edu/page/ulan/500015606
#
#                                                                   Artist Wikidata URL
# Artist Role Artist Display Name
# Artist      Anonymous, British, 19th century                                      NaN
# Designer    Margarete Willers                                                     NaN
# Artist      Adelaide Milton de Groot          https://www.wikidata.org/wiki/Q20936579
#
# [3 rows x 50 columns]

# %% [markdown]
# Para transformar o índice em duas colunas do DataFrame, usamos o método [`pandas.DataFrame.reset_index()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.reset_index.html).

# %%
data_all_join = data_all_join.reset_index()
data_all_join.sample(3)
# Out:
#                                     Artist Role  \
# 38                                       Artist
# 1620  Author|Translator|Publisher|Artist|Artist
# 2330                     Publisher|Lithographer
#
#                                     Artist Display Name  Unnamed: 0  \
# 38                                Allart van Everdingen      289734
# 1620  Ovid|Abbé Banier|Chez Despilly|Pierre François...      289765
# 2330                W. Duke, Sons & Co.|Knapp & Company      289426
#
#           Object Number  Is Highlight  Is Public Domain  Is Timeline Work  \
# 38              20.75.2         False             False              True
# 1620          17.3.1731         False             False             False
# 2330  63.350.205.106.84         False             False             False
#
#       Object ID           Department AccessionYear  ... Artist Prefix  \
# 38       427740  Drawings and Prints          1920  ...           NaN
# 1620     427788  Drawings and Prints          1917  ...         After
# 2330     427233  Drawings and Prints          1963  ...     Issued by
#
#                                      Artist Display Bio Artist Suffix  \
# 38                   Dutch, Alkmaar 1621–1675 Amsterdam           NaN
# 1620  Roman, Sulmo 43 B.C.–A.D. 17 Tomis, Moesia|Fre...           NaN
# 2330       New York and Durham, N.C.|American, New York           NaN
#
#                                       Artist Alpha Sort  \
# 38                               Everdingen, Allart van
# 1620  Ovid|Banier, Abbé|Chez Despilly|Basan, Pierre ...
# 2330                Duke, W. Sons & Co.|Knapp & Company
#
#                      Artist Nationality  \
# 38                                Dutch
# 1620  Roman|French|French|French|French
# 2330                  American|American
#
#                                 Artist Begin Date  \
# 38                                     1621
# 1620  -0043     |1700      |1723      |1741
# 2330                                   1870
#
#                                   Artist End Date Artist Gender  \
# 38                                     1675                 NaN
# 1620  0017      |1900      |1797      |1814                ||||
# 2330                                   1920                   |
#
#                                         Artist ULAN URL  Artist Wikidata URL
# 38           http://vocab.getty.edu/page/ulan/500115159                  NaN
# 1620  http://vocab.getty.edu/page/ulan/500246979|||h...                 ||||
# 2330                                                  |                    |
#
# [3 rows x 52 columns]

# %% [markdown]
# **Vejamos um exemplo de `append`**, que é semelhante a` concat`

# %%
data_object_1 = data_object.iloc[0:10, :]

columns_reverse = data_object.columns[ : : -1 ]
data_object_2 = data_object.iloc[10:20].loc[ : , columns_reverse]

print(data_object_1.shape)
print(data_object_2.shape)
# Out:
# (10, 42)
# (10, 42)

# %% [markdown]
# Usamos [pd.concat()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.concat.html) para anexar o dataframes.

# %%
data_object_1_2 = pd.concat([data_object_1, data_object_2], ignore_index = True)

print(data_object_1_2.shape)
data_object_1_2.sample(5)
# Out:
# (20, 42)
#     Unnamed: 0  Object Number  Is Highlight  Is Public Domain  \
# 15      155187        X.21.93         False             False
# 11      361913        X.144.1         False             False
# 8         5967  Inst.67.15.49         False             False
# 10      411903        Ref.113         False             False
# 5       471850     2019.601.1         False             False
#
#     Is Timeline Work  Object ID           Department AccessionYear  \
# 15              True     256657  Greek and Roman Art           NaN
# 11             False     569774         Egyptian Art           NaN
# 8              False       6370    The American Wing           NaN
# 10             False     708208  Drawings and Prints           NaN
# 5              False     838173    The American Wing           NaN
#
#            Object Name                                              Title  \
# 15  Statuette of a ram                          Bronze statuette of a ram
# 11   Shabti, Amen-meru                                 Shabti of Amenmeru
# 8                Plate                                              Plate
# 10               Print  Plate 7: the story of the Pisan saints, here S...
# 5              Drawing                                         Four Flies
#
#     ... Excavation River Classification Rights and Reproduction  \
# 15  ...        NaN   NaN        Bronzes                     NaN
# 11  ...        NaN   NaN            NaN                     NaN
# 8   ...        NaN   NaN       Ceramics                     NaN
# 10  ...        NaN   NaN         Prints                     NaN
# 5   ...        NaN   NaN       Drawings                     NaN
#
#                                         Link Resource Object Wikidata URL  \
# 15  http://www.metmuseum.org/art/collection/search...                 NaN
# 11  http://www.metmuseum.org/art/collection/search...                 NaN
# 8   http://www.metmuseum.org/art/collection/search...                 NaN
# 10  http://www.metmuseum.org/art/collection/search...                 NaN
# 5   http://www.metmuseum.org/art/collection/search...                 NaN
#
#    Metadata Date                                Repository  Tags  \
# 15           NaN  Metropolitan Museum of Art, New York, NY  Rams
# 11           NaN  Metropolitan Museum of Art, New York, NY   NaN
# 8            NaN  Metropolitan Museum of Art, New York, NY   NaN
# 10           NaN  Metropolitan Museum of Art, New York, NY   NaN
# 5            NaN  Metropolitan Museum of Art, New York, NY   NaN
#
#                                  Tags AAT URL
# 15  http://vocab.getty.edu/page/aat/300250287
# 11                                        NaN
# 8                                         NaN
# 10                                        NaN
# 5                                         NaN
#
# [5 rows x 42 columns]

# %% [markdown]
# ## Referências
#
# Python for Data Analysis. Wes McKinney. Cap 8.2
#
# - [Merge, join, concatenate and compare](https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html)
