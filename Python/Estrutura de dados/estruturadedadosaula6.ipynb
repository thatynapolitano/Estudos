# %% [markdown]
# ### Estrutura de dados - Aula 6
#
# ### Pilhas
#
# - Uma estrutura de dados é uma PILHA quando só conseguimos manipular o que está no seu topo.
#
# - O primeiro que entra é o último que sai.
#
# - <i> First In Last Out </i> (FILO)
#
# ### Aplicações
#
# - Recursividade
# - Cálculo de expressões matemáticas
# - Jogos de Cartas
#
# ### Manipulando Pilhas
#
# - O top é a única posição que conseguimos manipular.
# - Podemos implementar uma pilha com listas encadeadas ou com arrays.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Filas
#
# - Uma estrutura de dados é uma FILA quando inserimos somendo no final dela e removemos somente do seu início.
# - O primeiro que entra é o primeiro que sai.
# - <i> First In First Out </i> (FIFO)
#
# ### Aplicações
# - Fila de impressão.
# - Lista de reprodução de música.
# - Jogo Snake.
# - Senhas de Atendimento.
#
# ### Manipulando Filas
# - Inserimos no final (tail) e removemos do início (head).
# - Podemos implementar uma fila com listas encadeadas ou com arrays.

# %% [markdown]
# ![image.png](attachment:image.png)
